-- %%
select * from nleshin_catalog.bronze_layer.objects_description_journal

-- %%
select * from nleshin_catalog.bronze_layer.objects_description_mirror

-- %%
select * from nleshin_catalog.raw_layer.objects_description
