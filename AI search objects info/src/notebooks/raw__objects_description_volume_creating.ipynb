-- %%
-- Create new VOLUME objects_description
CREATE VOLUME IF NOT EXISTS nleshin_catalog.raw_layer.objects_description;

-- %%
-- List all files in the volume
LIST '/Volumes/nleshin_catalog/raw_layer/objects_description';

-- %% [markdown]
-- After that using UI i add new pdf files with description of different objects from "Source documents" folder
