-- %%
-- Step 1 - Creare raw table if not exists

-- drop table if exists nleshin_catalog.raw_layer.objects_description purge;

create table if not exists nleshin_catalog.raw_layer.objects_description;

-- %%
-- Step 2 - Load new files from volume to the raw table

COPY INTO nleshin_catalog.raw_layer.objects_description
FROM '/Volumes/nleshin_catalog/raw_layer/objects_description'
FILEFORMAT = BINARYFILE
COPY_OPTIONS ('mergeSchema' = 'true');
